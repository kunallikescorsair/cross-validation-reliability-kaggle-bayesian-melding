# %% [markdown]
# # Santander Experiment Notebook
#
# This notebook generates and analyses the Santander Customer Transaction Prediction experiment used in the cross-validation reliability research project.
#
# The purpose of this notebook is not to maximise Kaggle leaderboard rank. Instead, it creates a controlled empirical model-evaluation dataset by training many model configurations and recording their validation behaviour.
#
# ## Main Objectives
#
# This notebook performs the following steps:
#
# 1. Load the Santander training, test, and sample submission files.
# 2. Generate 1,000 controlled model configurations across multiple model families.
# 3. Evaluate each configuration using stratified 5-fold cross-validation.
# 4. Create Kaggle-compatible submission files.
# 5. Construct a representative 100-model leaderboard subset.
# 6. Merge manually verified public and private leaderboard scores.
# 7. Export the final Santander research dataset used in the Bayesian melding analysis.
#
# ## Final Outputs
#
# The main outputs are saved under:
#
# `results/santander/`
#
# Key output files include:
#
# - `santander_1000_model_configs.csv`
# - `santander_1000_model_results.csv`
# - `manual_submission_plan_100.csv`
# - `santander_leaderboard_scores.csv`
# - `santander_final_research_dataset.csv`
# - `santander_bayesian_melding_input.csv`
#
# ## Reproducibility Note
#
# Raw Kaggle competition data is not included in this repository. To reproduce the notebook, download the Santander Customer Transaction Prediction dataset from Kaggle and place the files in:
#
# `data/santander/`

# %% [markdown]
# ## 1. Setup
#
# This section imports the required Python libraries and sets the random seed used for reproducible model configuration generation.

# %%
import os
import json
import time
import warnings
import subprocess
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import roc_auc_score

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

warnings.filterwarnings("ignore")

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## 2. Project Paths
#
# This section defines the local project paths used by the notebook.
#
# Raw Kaggle data is expected under `data/santander/`.
#
# Experiment outputs are written to `results/santander/`.
#
# Generated submission files are written to `submissions/santander/`, which is ignored by Git because submission CSVs can be large and are not required for the final research analysis.

# %%
PROJECT_ROOT = Path("..")

DATA_DIR = PROJECT_ROOT / "data" / "santander"
SUBMISSION_DIR = PROJECT_ROOT / "submissions" / "santander"
RESULTS_DIR = PROJECT_ROOT / "results" / "santander"

SUBMISSION_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_PATH = DATA_DIR / "train.csv"
TEST_PATH = DATA_DIR / "test.csv"
SAMPLE_SUB_PATH = DATA_DIR / "sample_submission.csv"

COMPETITION_NAME = "santander-customer-transaction-prediction"

RESULTS_CSV = RESULTS_DIR / "santander_1000_model_results.csv"
CONFIG_CSV = RESULTS_DIR / "santander_1000_model_configs.csv"

print("Project root:", PROJECT_ROOT)
print("Data dir:", DATA_DIR)
print("Submission dir:", SUBMISSION_DIR)
print("Results dir:", RESULTS_DIR)
# Out:
# Project root: ..
# Data dir: ../data/santander
# Submission dir: ../submissions/santander
# Results dir: ../results/santander

# %% [markdown]
# ## 3. Experiment Controls
#
# This section controls which part of the 1,000-model configuration list is executed.
#
# For repository safety, the default range is empty:
#
# ```python
# START_INDEX = 0
# END_INDEX = 0
# ```
#
# To reproduce a small test batch, manually change the values to something like:
#
# ```python
# START_INDEX = 0
# END_INDEX = 5
# ```
#
# Kaggle auto-submission is disabled by default. Do not submit large batches automatically, as Kaggle may enforce submission limits or rate throttling.

# %%
# Default to an empty run for repository safety.
# Set START_INDEX and END_INDEX manually when reproducing experiments.
START_INDEX = 0
END_INDEX = 0

AUTO_SUBMIT = False
MAX_SUBMISSIONS_PER_RUN = 1

# 5-fold CV for all generated models.
cv_5 = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=RANDOM_STATE
)

print("START_INDEX:", START_INDEX)
print("END_INDEX:", END_INDEX)
print("AUTO_SUBMIT:", AUTO_SUBMIT)
print("MAX_SUBMISSIONS_PER_RUN:", MAX_SUBMISSIONS_PER_RUN)
# Out:
# START_INDEX: 700
# END_INDEX: 1000
# AUTO_SUBMIT: False
# MAX_SUBMISSIONS_PER_RUN: 1

# %% [markdown]
# ## 4. Load Santander Dataset

# %%
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
sample_sub = pd.read_csv(SAMPLE_SUB_PATH)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
print("Sample submission shape:", sample_sub.shape)

display(train_df.head())
display(sample_sub.head())
# Out:
# Train shape: (200000, 202)
# Test shape: (200000, 201)
# Sample submission shape: (200000, 2)
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]
#   ID_code  target
# 0  test_0       0
# 1  test_1       0
# 2  test_2       0
# 3  test_3       0
# 4  test_4       0

# %%
TARGET_COL = "target"
ID_COL = "ID_code"

feature_cols = [c for c in train_df.columns if c not in [ID_COL, TARGET_COL]]

X = train_df[feature_cols].copy()
y = train_df[TARGET_COL].copy()
X_test = test_df[feature_cols].copy()

print("Number of features:", len(feature_cols))
print("X shape:", X.shape)
print("y shape:", y.shape)
print("X_test shape:", X_test.shape)

print("\nTarget distribution:")
print(y.value_counts(normalize=True))
# Out:
# Number of features: 200
# X shape: (200000, 200)
# y shape: (200000,)
# X_test shape: (200000, 200)
#
# Target distribution:
# target
# 0    0.89951
# 1    0.10049
# Name: proportion, dtype: float64

# %% [markdown]
# ## 5. Generate 1000 Controlled Model Configurations
#
# The experiment uses five model families:
#
# - LightGBM: 350 configurations
# - XGBoost: 350 configurations
# - CatBoost: 150 configurations
# - Random Forest / ExtraTrees: 75 configurations
# - Logistic Regression: 75 configurations
#
# This gives 1000 model configurations for the Santander dataset.

# %%
def sample_lgbm_config(rng, model_id):
    return {
        "model_id": model_id,
        "model_family": "lightgbm",
        "seed": int(rng.integers(1, 1_000_000)),
        "params": {
            "n_estimators": int(rng.choice([300, 500, 700, 900, 1100])),
            "learning_rate": float(rng.choice([0.01, 0.02, 0.03, 0.05, 0.07])),
            "num_leaves": int(rng.choice([15, 31, 63, 127])),
            "max_depth": int(rng.choice([-1, 3, 5, 7, 9])),
            "min_child_samples": int(rng.choice([10, 20, 40, 80, 120])),
            "subsample": float(rng.choice([0.6, 0.7, 0.8, 0.9, 1.0])),
            "colsample_bytree": float(rng.choice([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])),
            "reg_alpha": float(rng.choice([0.0, 0.01, 0.1, 0.5, 1.0])),
            "reg_lambda": float(rng.choice([0.0, 0.1, 0.5, 1.0, 2.0, 5.0])),
        }
    }


def sample_xgb_config(rng, model_id):
    return {
        "model_id": model_id,
        "model_family": "xgboost",
        "seed": int(rng.integers(1, 1_000_000)),
        "params": {
            "n_estimators": int(rng.choice([300, 500, 700, 900, 1100])),
            "learning_rate": float(rng.choice([0.01, 0.02, 0.03, 0.05, 0.07])),
            "max_depth": int(rng.choice([3, 4, 5, 6, 7])),
            "min_child_weight": float(rng.choice([1, 2, 3, 5, 8, 10])),
            "gamma": float(rng.choice([0.0, 0.01, 0.05, 0.1, 0.3])),
            "subsample": float(rng.choice([0.6, 0.7, 0.8, 0.9, 1.0])),
            "colsample_bytree": float(rng.choice([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])),
            "reg_alpha": float(rng.choice([0.0, 0.01, 0.1, 0.5, 1.0])),
            "reg_lambda": float(rng.choice([0.1, 0.5, 1.0, 2.0, 5.0])),
        }
    }


def sample_catboost_config(rng, model_id):
    return {
        "model_id": model_id,
        "model_family": "catboost",
        "seed": int(rng.integers(1, 1_000_000)),
        "params": {
            "iterations": int(rng.choice([300, 500, 700, 900])),
            "learning_rate": float(rng.choice([0.01, 0.02, 0.03, 0.05, 0.07])),
            "depth": int(rng.choice([4, 5, 6, 7, 8])),
            "l2_leaf_reg": float(rng.choice([1, 3, 5, 7, 10])),
            "random_strength": float(rng.choice([0.5, 1.0, 2.0, 5.0])),
            "bagging_temperature": float(rng.choice([0.0, 0.5, 1.0, 2.0])),
        }
    }


def sample_tree_config(rng, model_id):
    model_family = str(rng.choice(["random_forest", "extra_trees"]))

    return {
        "model_id": model_id,
        "model_family": model_family,
        "seed": int(rng.integers(1, 1_000_000)),
        "params": {
            "n_estimators": int(rng.choice([200, 300, 500])),
            "max_depth": rng.choice([None, 5, 8, 12, 16, 24]).item() if hasattr(rng.choice([None, 5]), "item") else None,
            "min_samples_split": int(rng.choice([2, 5, 10, 20])),
            "min_samples_leaf": int(rng.choice([1, 2, 4, 8])),
            "max_features": str(rng.choice(["sqrt", "log2"])),
            "bootstrap": bool(rng.choice([True, False])) if model_family == "random_forest" else False,
        }
    }


def sample_logreg_config(rng, model_id):
    penalty = str(rng.choice(["l2", "l1"]))
    solver = "liblinear" if penalty == "l1" else str(rng.choice(["lbfgs", "liblinear"]))

    return {
        "model_id": model_id,
        "model_family": "logistic_regression",
        "seed": int(rng.integers(1, 1_000_000)),
        "params": {
            "C": float(rng.choice([0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1.0, 3.0, 10.0])),
            "penalty": penalty,
            "solver": solver,
            "max_iter": 1000,
        }
    }

# %%
def create_model_configs(random_state=42):
    rng = np.random.default_rng(random_state)
    configs = []
    model_id = 0

    # LightGBM: 350
    for _ in range(350):
        configs.append(sample_lgbm_config(rng, model_id))
        model_id += 1

    # XGBoost: 350
    for _ in range(350):
        configs.append(sample_xgb_config(rng, model_id))
        model_id += 1

    # CatBoost: 150
    for _ in range(150):
        configs.append(sample_catboost_config(rng, model_id))
        model_id += 1

    # Random Forest / ExtraTrees: 75
    for _ in range(75):
        configs.append(sample_tree_config(rng, model_id))
        model_id += 1

    # Logistic Regression: 75
    for _ in range(75):
        configs.append(sample_logreg_config(rng, model_id))
        model_id += 1

    return configs


model_configs = create_model_configs(RANDOM_STATE)

print("Total configs:", len(model_configs))
pd.DataFrame([
    {
        "model_id": c["model_id"],
        "model_family": c["model_family"],
        "seed": c["seed"],
        "params_json": json.dumps(c["params"])
    }
    for c in model_configs
]).to_csv(CONFIG_CSV, index=False)

print("Saved config table to:", CONFIG_CSV)

display(pd.DataFrame(model_configs).head())
# Out:
# Total configs: 1000
# Saved config table to: ../results/santander/santander_1000_model_configs.csv
#    model_id model_family    seed  \
# 0         0     lightgbm   89251
# 1         1     lightgbm  526479
# 2         2     lightgbm  500352
# 3         3     lightgbm  450460
# 4         4     lightgbm  165229
#
#                                               params
# 0  {'n_estimators': 900, 'learning_rate': 0.05, '...
# 1  {'n_estimators': 1100, 'learning_rate': 0.05, ...
# 2  {'n_estimators': 500, 'learning_rate': 0.01, '...
# 3  {'n_estimators': 500, 'learning_rate': 0.01, '...
# 4  {'n_estimators': 900, 'learning_rate': 0.05, '...

# %%
# Clean max_depth values in tree-based sklearn configs.
# This prevents weird numpy object issues from random sampling.

for config in model_configs:
    if config["model_family"] in ["random_forest", "extra_trees"]:
        md = config["params"].get("max_depth", None)
        if pd.isna(md):
            config["params"]["max_depth"] = None
        elif md is not None:
            config["params"]["max_depth"] = int(md)

# %% [markdown]
# ## 6. Build Model Pipelines
#
# Each model family uses a consistent preprocessing pipeline.
#
# - Tree/boosting models use median imputation.
# - Logistic Regression uses median imputation + standard scaling.

# %%
def build_pipeline(config):
    family = config["model_family"]
    params = config["params"].copy()
    seed = config["seed"]

    if family == "lightgbm":
        model = LGBMClassifier(
            **params,
            objective="binary",
            random_state=seed,
            n_jobs=-1,
            verbosity=-1
        )

        pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("model", model)
        ])

    elif family == "xgboost":
        model = XGBClassifier(
            **params,
            objective="binary:logistic",
            eval_metric="auc",
            random_state=seed,
            n_jobs=-1,
            tree_method="hist"
        )

        pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("model", model)
        ])

    elif family == "catboost":
        model = CatBoostClassifier(
            **params,
            loss_function="Logloss",
            eval_metric="AUC",
            random_seed=seed,
            verbose=False,
            allow_writing_files=False
        )

        pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("model", model)
        ])

    elif family == "random_forest":
        model = RandomForestClassifier(
            **params,
            random_state=seed,
            n_jobs=-1,
            class_weight=None
        )

        pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("model", model)
        ])

    elif family == "extra_trees":
        params.pop("bootstrap", None)

        model = ExtraTreesClassifier(
            **params,
            random_state=seed,
            n_jobs=-1,
            class_weight=None
        )

        pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("model", model)
        ])

    elif family == "logistic_regression":
        model = LogisticRegression(
            **params,
            random_state=seed
        )

        pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", StandardScaler()),
            ("model", model)
        ])

    else:
        raise ValueError(f"Unknown model family: {family}")

    return pipeline

# %% [markdown]
# ## 7. Kaggle Submission Helpers
#
# These functions:
#
# 1. Create a submission CSV
# 2. Submit the CSV to Kaggle if `AUTO_SUBMIT=True`
# 3. Read the latest Kaggle public/private score
# 4. Return those scores for storage in the results CSV
#
# Important: submit in small batches only.

# %%
def run_shell_command(command, timeout=300):
    """
    Run a shell command and return stdout/stderr.
    """
    try:
        completed = subprocess.run(
            command,
            shell=True,
            capture_output=True,
            text=True,
            timeout=timeout
        )
        return completed.returncode, completed.stdout, completed.stderr
    except subprocess.TimeoutExpired:
        return 1, "", "Command timed out"


def create_submission(model_id, pipeline, X, y, X_test, sample_sub, submission_dir):
    """
    Fit model on full training data and save test predictions.
    """
    pipeline.fit(X, y)

    test_pred = pipeline.predict_proba(X_test)[:, 1]

    submission = sample_sub.copy()
    submission["target"] = test_pred

    submission_path = submission_dir / f"santander_model_{model_id:04d}.csv"
    submission.to_csv(submission_path, index=False)

    return submission_path


def submit_to_kaggle(submission_path, model_id, model_family):
    """
    Submit a CSV to Kaggle.
    """
    message = f"Santander model {model_id:04d} {model_family}"

    command = (
        f'kaggle competitions submit '
        f'-c {COMPETITION_NAME} '
        f'-f "{submission_path}" '
        f'-m "{message}"'
    )

    returncode, stdout, stderr = run_shell_command(command, timeout=600)

    success = returncode == 0 and "Successfully submitted" in stdout

    return {
        "submitted_to_kaggle": success,
        "submit_stdout": stdout,
        "submit_stderr": stderr
    }


def fetch_kaggle_submissions():
    """
    Fetch Kaggle submissions table using the Kaggle CLI.
    """
    command = f"kaggle competitions submissions -c {COMPETITION_NAME}"
    returncode, stdout, stderr = run_shell_command(command, timeout=300)

    if returncode != 0:
        print("Could not fetch submissions.")
        print(stderr)
        return None

    print(stdout)
    return stdout


def parse_latest_scores_from_cli_output(stdout, filename):
    """
    Parse public/private scores from Kaggle CLI output.

    This is a simple parser based on matching the file name line.
    It may need adjustment if Kaggle CLI output format changes.
    """
    if stdout is None:
        return None, None, "NO_OUTPUT"

    lines = stdout.splitlines()

    matching_lines = [line for line in lines if filename in line]

    if len(matching_lines) == 0:
        return None, None, "NOT_FOUND"

    line = matching_lines[0]
    parts = line.split()

    # Public and private scores are usually the last two columns.
    try:
        public_score = float(parts[-2])
        private_score = float(parts[-1])
        status = "COMPLETE"
    except Exception:
        public_score = None
        private_score = None
        status = "PARSE_FAILED"

    return public_score, private_score, status

# %% [markdown]
# ## 8. Evaluation Function
#
# For each model configuration, we calculate 5-fold CV AUC.
#
# Then we fit on the full training set and create a submission file.
#
# If `AUTO_SUBMIT=True`, the notebook submits the file to Kaggle and tries to collect public/private scores automatically.

# %%
def evaluate_single_config(config, X, y, X_test, sample_sub, auto_submit=False):
    model_id = config["model_id"]
    family = config["model_family"]
    seed = config["seed"]
    params = config["params"]

    print(f"\nRunning model_id={model_id}, family={family}")

    pipeline = build_pipeline(config)

    start_time = time.time()

    result = {
        "competition": "santander",
        "model_id": model_id,
        "model_family": family,
        "seed": seed,
        "params_json": json.dumps(params),
        "started_at": datetime.now().isoformat(),
        "cv_auc_mean": None,
        "cv_auc_std": None,
        "cv_auc_min": None,
        "cv_auc_max": None,
        "submission_path": None,
        "submitted_to_kaggle": False,
        "kaggle_status": None,
        "public_auc": None,
        "private_auc": None,
        "runtime_seconds": None,
        "error": None
    }

    try:
        cv_scores = cross_val_score(
            pipeline,
            X,
            y,
            scoring="roc_auc",
            cv=cv_5,
            n_jobs=-1
        )

        result["cv_auc_mean"] = float(np.mean(cv_scores))
        result["cv_auc_std"] = float(np.std(cv_scores))
        result["cv_auc_min"] = float(np.min(cv_scores))
        result["cv_auc_max"] = float(np.max(cv_scores))

        print("CV AUC mean:", result["cv_auc_mean"])
        print("CV AUC std:", result["cv_auc_std"])

        submission_path = create_submission(
            model_id=model_id,
            pipeline=pipeline,
            X=X,
            y=y,
            X_test=X_test,
            sample_sub=sample_sub,
            submission_dir=SUBMISSION_DIR
        )

        result["submission_path"] = str(submission_path)

        if auto_submit:
            submit_result = submit_to_kaggle(
                submission_path=submission_path,
                model_id=model_id,
                model_family=family
            )

            result["submitted_to_kaggle"] = bool(submit_result["submitted_to_kaggle"])

            if result["submitted_to_kaggle"]:
                print("Submitted successfully. Waiting before fetching score...")
                time.sleep(90)

                stdout = fetch_kaggle_submissions()

                public_auc, private_auc, status = parse_latest_scores_from_cli_output(
                    stdout=stdout,
                    filename=submission_path.name
                )

                result["public_auc"] = public_auc
                result["private_auc"] = private_auc
                result["kaggle_status"] = status
            else:
                result["kaggle_status"] = "SUBMISSION_FAILED"
                result["error"] = submit_result["submit_stderr"]

    except Exception as e:
        result["error"] = repr(e)
        print("ERROR:", repr(e))

    result["runtime_seconds"] = float(time.time() - start_time)
    result["finished_at"] = datetime.now().isoformat()

    return result

# %% [markdown]
# ## 9. Resume Existing Results
#
# This cell loads existing results if the notebook has already been run before.
#
# This allows the experiment to resume without repeating completed models.

# %%
if RESULTS_CSV.exists():
    existing_results_df = pd.read_csv(RESULTS_CSV)
    completed_ids = set(existing_results_df["model_id"].astype(int).tolist())
    print("Loaded existing results:", existing_results_df.shape)
    print("Completed model ids:", len(completed_ids))
else:
    existing_results_df = pd.DataFrame()
    completed_ids = set()
    print("No existing results found.")
# Out:
# Loaded existing results: (50, 22)
# Completed model ids: 50

# %% [markdown]
# ## 10. Run Experiment Batch
#
# Start with a small batch.
#
# Recommended first run:
#
# ```python
# START_INDEX = 0
# END_INDEX = 5
# AUTO_SUBMIT = False
# ```
#
# After confirming everything works, increase the range.
#
# When submitting to Kaggle, keep `MAX_SUBMISSIONS_PER_RUN` small.

# %%
batch_configs = model_configs[START_INDEX:END_INDEX]

new_results = []
submission_count = 0

for config in batch_configs:
    model_id = int(config["model_id"])

    if model_id in completed_ids:
        print(f"Skipping model_id={model_id}; already completed.")
        continue

    should_submit = AUTO_SUBMIT and (submission_count < MAX_SUBMISSIONS_PER_RUN)

    result = evaluate_single_config(
        config=config,
        X=X,
        y=y,
        X_test=X_test,
        sample_sub=sample_sub,
        auto_submit=should_submit
    )

    if should_submit:
        submission_count += 1

    new_results.append(result)

    # Save after every model so progress is not lost.
    temp_df = pd.DataFrame(new_results)

    if RESULTS_CSV.exists():
        old_df = pd.read_csv(RESULTS_CSV)
        combined_df = pd.concat([old_df, temp_df], ignore_index=True)
        combined_df = combined_df.drop_duplicates(subset=["model_id"], keep="last")
    else:
        combined_df = temp_df.copy()

    combined_df.to_csv(RESULTS_CSV, index=False)

    print(f"Saved progress to {RESULTS_CSV}")

print("Batch complete.")
print("New results:", len(new_results))
# Out:
# Running model_id=700, family=catboost
# CV AUC mean: 0.8812214088275916
# CV AUC std: 0.0032218444009095215
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=701, family=catboost
# CV AUC mean: 0.8435717996745062
# CV AUC std: 0.003256046739515433
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=702, family=catboost
# CV AUC mean: 0.8891603360054126
# CV AUC std: 0.0032978782559411465
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=703, family=catboost
# CV AUC mean: 0.8580081007311506
# CV AUC std: 0.0032126806920209226
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=704, family=catboost
# CV AUC mean: 0.8936698940706872
# CV AUC std: 0.00287307244231774
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=705, family=catboost
# CV AUC mean: 0.8935631513900217
# CV AUC std: 0.002687402803253725
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=706, family=catboost
# CV AUC mean: 0.8582975777029909
# CV AUC std: 0.003921885914340138
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=707, family=catboost
# CV AUC mean: 0.873409299211729
# CV AUC std: 0.0035703678167213534
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=708, family=catboost
# CV AUC mean: 0.8847619870426089
# CV AUC std: 0.00315310411516763
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=709, family=catboost
# CV AUC mean: 0.8145515698487081
# CV AUC std: 0.005258196950635847
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=710, family=catboost
# CV AUC mean: 0.8737389764877319
# CV AUC std: 0.002852244425560584
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=711, family=catboost
# CV AUC mean: 0.8677335042664552
# CV AUC std: 0.0033528495899889585
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=712, family=catboost
# CV AUC mean: 0.8428577345226944
# CV AUC std: 0.003983302190166537
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=713, family=catboost
# CV AUC mean: 0.8896390959759513
# CV AUC std: 0.002918949846481552
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=714, family=catboost
# CV AUC mean: 0.8901169673514501
# CV AUC std: 0.003285250869241375
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=715, family=catboost
# CV AUC mean: 0.8645026859370979
# CV AUC std: 0.0031479151725604293
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=716, family=catboost
# CV AUC mean: 0.8928831570118667
# CV AUC std: 0.0031721220608897853
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=717, family=catboost
# CV AUC mean: 0.8890737141518729
# CV AUC std: 0.003255893455424778
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=718, family=catboost
# CV AUC mean: 0.8864426280627598
# CV AUC std: 0.0033140221686087904
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=719, family=catboost
# CV AUC mean: 0.8777126245217278
# CV AUC std: 0.003192800775932396
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=720, family=catboost
# CV AUC mean: 0.8516321630665056
# CV AUC std: 0.0035593555035274807
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=721, family=catboost
# CV AUC mean: 0.8656541146443046
# CV AUC std: 0.00336140915430558
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=722, family=catboost
# CV AUC mean: 0.882195236049878
# CV AUC std: 0.003087330536492305
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=723, family=catboost
# CV AUC mean: 0.892323637897291
# CV AUC std: 0.0030549206098404716
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=724, family=catboost
# CV AUC mean: 0.8936131765855077
# CV AUC std: 0.0030673918614425397
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=725, family=catboost
# CV AUC mean: 0.8711182663899842
# CV AUC std: 0.0032706847194675054
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=726, family=catboost
# CV AUC mean: 0.8790026325888398
# CV AUC std: 0.00337672837082276
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=727, family=catboost
# CV AUC mean: 0.888893887338571
# CV AUC std: 0.002812384312838571
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=728, family=catboost
# CV AUC mean: 0.85887886563191
# CV AUC std: 0.003468401748964431
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=729, family=catboost
# CV AUC mean: 0.8917012371948921
# CV AUC std: 0.0028816607893108076
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=730, family=catboost
# CV AUC mean: 0.8380826958335431
# CV AUC std: 0.004181048180783441
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=731, family=catboost
# CV AUC mean: 0.8441619157708136
# CV AUC std: 0.0032728438593834777
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=732, family=catboost
# CV AUC mean: 0.8839388137417432
# CV AUC std: 0.003095791923112694
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=733, family=catboost
# CV AUC mean: 0.8411497066858835
# CV AUC std: 0.0035341647183387195
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=734, family=catboost
# CV AUC mean: 0.8864684208664032
# CV AUC std: 0.0033640758504718438
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=735, family=catboost
# CV AUC mean: 0.8874139135377958
# CV AUC std: 0.0032058515024649364
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=736, family=catboost
# CV AUC mean: 0.8765737320581737
# CV AUC std: 0.003522548412055769
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=737, family=catboost
# CV AUC mean: 0.8770047502964365
# CV AUC std: 0.003266491591484485
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=738, family=catboost
# CV AUC mean: 0.8653274154434513
# CV AUC std: 0.0032871685695814966
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=739, family=catboost
# CV AUC mean: 0.8499669181811298
# CV AUC std: 0.0037730685580759865
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=740, family=catboost
# CV AUC mean: 0.8279727257043458
# CV AUC std: 0.004439910925532839
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=741, family=catboost
# CV AUC mean: 0.8743201061069709
# CV AUC std: 0.003366096081000745
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=742, family=catboost
# CV AUC mean: 0.8598288791161511
# CV AUC std: 0.002727451347930942
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=743, family=catboost
# CV AUC mean: 0.8744535968321081
# CV AUC std: 0.003376133295503283
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=744, family=catboost
# CV AUC mean: 0.857893345545671
# CV AUC std: 0.0036617874872644594
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=745, family=catboost
# CV AUC mean: 0.8756884998954858
# CV AUC std: 0.003250232744768956
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=746, family=catboost
# CV AUC mean: 0.8862706601044478
# CV AUC std: 0.0032275448259931287
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=747, family=catboost
# CV AUC mean: 0.8496366131408589
# CV AUC std: 0.0033820829312478807
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=748, family=catboost
# CV AUC mean: 0.8633994032766715
# CV AUC std: 0.00333708445643778
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=749, family=catboost
# CV AUC mean: 0.8321454943279367
# CV AUC std: 0.004888422091395535
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=750, family=catboost
# CV AUC mean: 0.8671028253631607
# CV AUC std: 0.0034096354508839385
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=751, family=catboost
# CV AUC mean: 0.816598372479549
# CV AUC std: 0.004526324835370304
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=752, family=catboost
# CV AUC mean: 0.868573569359152
# CV AUC std: 0.003486010323524339
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=753, family=catboost
# CV AUC mean: 0.8675022596530164
# CV AUC std: 0.0034104310981269755
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=754, family=catboost
# CV AUC mean: 0.8384136525105307
# CV AUC std: 0.0036165164094001242
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=755, family=catboost
# CV AUC mean: 0.8729140445087216
# CV AUC std: 0.0033357831335203213
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=756, family=catboost
# CV AUC mean: 0.8426405129563669
# CV AUC std: 0.0033788153117942413
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=757, family=catboost
# CV AUC mean: 0.848241820336081
# CV AUC std: 0.003908173856730765
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=758, family=catboost
# CV AUC mean: 0.8275815073994206
# CV AUC std: 0.004004012522902044
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=759, family=catboost
# CV AUC mean: 0.8929838802295744
# CV AUC std: 0.0029113511383119617
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=760, family=catboost
# CV AUC mean: 0.8769207676989919
# CV AUC std: 0.003052264518751633
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=761, family=catboost
# CV AUC mean: 0.8938081884942395
# CV AUC std: 0.002662881674825177
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=762, family=catboost
# CV AUC mean: 0.895085439211255
# CV AUC std: 0.002767108829552501
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=763, family=catboost
# CV AUC mean: 0.890738035374072
# CV AUC std: 0.003143183314966199
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=764, family=catboost
# CV AUC mean: 0.893811745619073
# CV AUC std: 0.002917113871951604
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=765, family=catboost
# CV AUC mean: 0.8554907458055926
# CV AUC std: 0.0038929648584107492
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=766, family=catboost
# CV AUC mean: 0.8749931501642727
# CV AUC std: 0.0025670256119456557
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=767, family=catboost
# CV AUC mean: 0.8708526809312749
# CV AUC std: 0.0034633929072939934
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=768, family=catboost
# CV AUC mean: 0.8869236067870571
# CV AUC std: 0.003195626523041082
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=769, family=catboost
# CV AUC mean: 0.8944599438650108
# CV AUC std: 0.0030237899000782995
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=770, family=catboost
# CV AUC mean: 0.8519139993064068
# CV AUC std: 0.0035964360367878147
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=771, family=catboost
# CV AUC mean: 0.8681822199792583
# CV AUC std: 0.003611526218846458
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=772, family=catboost
# CV AUC mean: 0.8740693793257295
# CV AUC std: 0.0031935125584973715
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=773, family=catboost
# CV AUC mean: 0.8551076875600379
# CV AUC std: 0.0034917359604276273
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=774, family=catboost
# CV AUC mean: 0.8788594429992784
# CV AUC std: 0.0031597320837509135
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=775, family=catboost
# CV AUC mean: 0.8683469061161727
# CV AUC std: 0.003244779961226773
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=776, family=catboost
# CV AUC mean: 0.828728209817266
# CV AUC std: 0.00413581532592431
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=777, family=catboost
# CV AUC mean: 0.8821036415549164
# CV AUC std: 0.0030537608874037503
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=778, family=catboost
# CV AUC mean: 0.8792333073342237
# CV AUC std: 0.0033546066285179564
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=779, family=catboost
# CV AUC mean: 0.8810772376976214
# CV AUC std: 0.0030385640169479393
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=780, family=catboost
# CV AUC mean: 0.8863243668741874
# CV AUC std: 0.003307083071366967
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=781, family=catboost
# CV AUC mean: 0.8907893074541031
# CV AUC std: 0.002855396265287205
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=782, family=catboost
# CV AUC mean: 0.8788297023653046
# CV AUC std: 0.0034772014093518017
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=783, family=catboost
# CV AUC mean: 0.8089791209463216
# CV AUC std: 0.004705869419396653
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=784, family=catboost
# CV AUC mean: 0.8701948901024709
# CV AUC std: 0.003484333566982832
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=785, family=catboost
# CV AUC mean: 0.8194799020322616
# CV AUC std: 0.004179717292903941
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=786, family=catboost
# CV AUC mean: 0.8372266024226349
# CV AUC std: 0.003762446223399444
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=787, family=catboost
# CV AUC mean: 0.8600308531847288
# CV AUC std: 0.003005012774538418
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=788, family=catboost
# CV AUC mean: 0.8867291786206455
# CV AUC std: 0.002782963454999336
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=789, family=catboost
# CV AUC mean: 0.8543206397395988
# CV AUC std: 0.0032635723032886084
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=790, family=catboost
# CV AUC mean: 0.8756519048273936
# CV AUC std: 0.0032994284994833853
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=791, family=catboost
# CV AUC mean: 0.8932785156046457
# CV AUC std: 0.002897954411074627
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=792, family=catboost
# CV AUC mean: 0.8434872794334858
# CV AUC std: 0.003307761263398571
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=793, family=catboost
# CV AUC mean: 0.8310520842971394
# CV AUC std: 0.00359760319967308
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=794, family=catboost
# CV AUC mean: 0.8792543689138149
# CV AUC std: 0.003030361654348522
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=795, family=catboost
# CV AUC mean: 0.8507123451160442
# CV AUC std: 0.0034625710859775244
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=796, family=catboost
# CV AUC mean: 0.859320485495551
# CV AUC std: 0.003370978146390553
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=797, family=catboost
# CV AUC mean: 0.8936100228674263
# CV AUC std: 0.002976392318516977
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=798, family=catboost
# CV AUC mean: 0.8832211732684243
# CV AUC std: 0.0032162114841664214
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=799, family=catboost
# CV AUC mean: 0.8749290349678803
# CV AUC std: 0.0032576034739158414
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=800, family=catboost
# CV AUC mean: 0.8764797835994115
# CV AUC std: 0.002934343216835984
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=801, family=catboost
# CV AUC mean: 0.8644969147480766
# CV AUC std: 0.00328586467303712
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=802, family=catboost
# CV AUC mean: 0.8885575734269724
# CV AUC std: 0.0032869939509595253
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=803, family=catboost
# CV AUC mean: 0.8815752002143531
# CV AUC std: 0.003457030918512215
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=804, family=catboost
# CV AUC mean: 0.8620164540649442
# CV AUC std: 0.003491876426558679
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=805, family=catboost
# CV AUC mean: 0.8889174808322927
# CV AUC std: 0.0030632343986486143
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=806, family=catboost
# CV AUC mean: 0.8283898986530417
# CV AUC std: 0.0044342813226794795
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=807, family=catboost
# CV AUC mean: 0.8468231982535427
# CV AUC std: 0.004041495581299915
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=808, family=catboost
# CV AUC mean: 0.8812752450677882
# CV AUC std: 0.003299089856021568
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=809, family=catboost
# CV AUC mean: 0.8928410102112301
# CV AUC std: 0.0031316311532176046
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=810, family=catboost
# CV AUC mean: 0.8884171467709028
# CV AUC std: 0.003252676735234641
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=811, family=catboost
# CV AUC mean: 0.8576075112795758
# CV AUC std: 0.0031895096693742796
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=812, family=catboost
# CV AUC mean: 0.8843874446310143
# CV AUC std: 0.003133202326998385
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=813, family=catboost
# CV AUC mean: 0.8284828520075658
# CV AUC std: 0.003962685848119492
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=814, family=catboost
# CV AUC mean: 0.8438254352278415
# CV AUC std: 0.003910024497878716
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=815, family=catboost
# CV AUC mean: 0.8382178083319832
# CV AUC std: 0.003518620781923033
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=816, family=catboost
# CV AUC mean: 0.888686811111636
# CV AUC std: 0.003093082481259252
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=817, family=catboost
# CV AUC mean: 0.8490331296394983
# CV AUC std: 0.0040070570660599766
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=818, family=catboost
# CV AUC mean: 0.8542067212098404
# CV AUC std: 0.003222576379441956
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=819, family=catboost
# CV AUC mean: 0.8728718234931258
# CV AUC std: 0.003287613383726094
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=820, family=catboost
# CV AUC mean: 0.8921356137654609
# CV AUC std: 0.0030327705953035766
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=821, family=catboost
# CV AUC mean: 0.8391028511354657
# CV AUC std: 0.004575934000188215
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=822, family=catboost
# CV AUC mean: 0.7953305202985157
# CV AUC std: 0.007862369165469984
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=823, family=catboost
# CV AUC mean: 0.8678949277035288
# CV AUC std: 0.003361601804928666
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=824, family=catboost
# CV AUC mean: 0.8369047940661505
# CV AUC std: 0.003710747211467606
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=825, family=catboost
# CV AUC mean: 0.8735730493745628
# CV AUC std: 0.003297095269837544
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=826, family=catboost
# CV AUC mean: 0.8515124068837032
# CV AUC std: 0.0033876821506710316
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=827, family=catboost
# CV AUC mean: 0.8702751854014114
# CV AUC std: 0.003361768231551571
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=828, family=catboost
# CV AUC mean: 0.8632886367737805
# CV AUC std: 0.0033817552893267043
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=829, family=catboost
# CV AUC mean: 0.8925544554313218
# CV AUC std: 0.002738909409890051
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=830, family=catboost
# CV AUC mean: 0.8681752965034125
# CV AUC std: 0.0037386109320555368
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=831, family=catboost
# CV AUC mean: 0.8496836456755169
# CV AUC std: 0.0032462678688517403
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=832, family=catboost
# CV AUC mean: 0.8817507701815629
# CV AUC std: 0.003330764062983092
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=833, family=catboost
# CV AUC mean: 0.873598883134356
# CV AUC std: 0.0032244410594895983
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=834, family=catboost
# CV AUC mean: 0.8929914717562722
# CV AUC std: 0.002830144947839362
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=835, family=catboost
# CV AUC mean: 0.8360116818035802
# CV AUC std: 0.0037286605557818953
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=836, family=catboost
# CV AUC mean: 0.8548539684155833
# CV AUC std: 0.004232592069661095
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=837, family=catboost
# CV AUC mean: 0.8550011944492816
# CV AUC std: 0.00309157341589713
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=838, family=catboost
# CV AUC mean: 0.8281643514702471
# CV AUC std: 0.0037850405055251733
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=839, family=catboost
# CV AUC mean: 0.8489373855273865
# CV AUC std: 0.003917513330757848
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=840, family=catboost
# CV AUC mean: 0.8826679535015274
# CV AUC std: 0.0029526084274479657
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=841, family=catboost
# CV AUC mean: 0.8172321212237206
# CV AUC std: 0.00435361065338995
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=842, family=catboost
# CV AUC mean: 0.8550943394135025
# CV AUC std: 0.0033292158443331862
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=843, family=catboost
# CV AUC mean: 0.8902713267438959
# CV AUC std: 0.0031371471343225083
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=844, family=catboost
# CV AUC mean: 0.83410762070845
# CV AUC std: 0.004945471959354698
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=845, family=catboost
# CV AUC mean: 0.8440072904314032
# CV AUC std: 0.0033345349400992646
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=846, family=catboost
# CV AUC mean: 0.878808255020509
# CV AUC std: 0.0032334116423627275
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=847, family=catboost
# CV AUC mean: 0.8862710585023432
# CV AUC std: 0.0032554742535798376
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=848, family=catboost
# CV AUC mean: 0.887353831430674
# CV AUC std: 0.002887175432870423
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=849, family=catboost
# CV AUC mean: 0.8776258549907088
# CV AUC std: 0.002654747250677071
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=850, family=extra_trees
# CV AUC mean: 0.864718856435392
# CV AUC std: 0.0027978769549735125
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=851, family=extra_trees
# CV AUC mean: 0.8470959679777079
# CV AUC std: 0.004176092311616885
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=852, family=extra_trees
# CV AUC mean: 0.8502983374312448
# CV AUC std: 0.0030083635681938336
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=853, family=extra_trees
# CV AUC mean: 0.8712198131722844
# CV AUC std: 0.0037233757090687765
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=854, family=extra_trees
# CV AUC mean: 0.8686180795354712
# CV AUC std: 0.0032986983204779125
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=855, family=extra_trees
# CV AUC mean: 0.8707519067286471
# CV AUC std: 0.0035690141946709774
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=856, family=random_forest
# CV AUC mean: 0.8442131303866383
# CV AUC std: 0.0031685605627300357
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=857, family=extra_trees
# CV AUC mean: 0.8716728898223798
# CV AUC std: 0.003944730375834757
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=858, family=extra_trees
# CV AUC mean: 0.8439156933399177
# CV AUC std: 0.0031447511929438075
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=859, family=extra_trees
# CV AUC mean: 0.868417274770794
# CV AUC std: 0.00390699929500632
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=860, family=extra_trees
# CV AUC mean: 0.8704532333073942
# CV AUC std: 0.003946742712712229
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=861, family=random_forest
# CV AUC mean: 0.8628693643287575
# CV AUC std: 0.004091508114868339
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=862, family=extra_trees
# CV AUC mean: 0.83335774096743
# CV AUC std: 0.004775387807854397
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=863, family=extra_trees
# CV AUC mean: 0.8552066993357702
# CV AUC std: 0.0034540734493009265
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=864, family=random_forest
# CV AUC mean: 0.8411131955003066
# CV AUC std: 0.004692882945179933
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=865, family=random_forest
# CV AUC mean: 0.8548143403816855
# CV AUC std: 0.003900534039757328
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=866, family=random_forest
# CV AUC mean: 0.8571344134616068
# CV AUC std: 0.003978740955573248
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=867, family=extra_trees
# CV AUC mean: 0.8441734426961078
# CV AUC std: 0.0020028547297197647
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=868, family=extra_trees
# CV AUC mean: 0.8573638703475759
# CV AUC std: 0.004011077205043726
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=869, family=random_forest
# CV AUC mean: 0.8473154129364662
# CV AUC std: 0.00428149968266096
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=870, family=extra_trees
# CV AUC mean: 0.8718072374252381
# CV AUC std: 0.002525392698952069
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=871, family=random_forest
# CV AUC mean: 0.8621901504098316
# CV AUC std: 0.004063192254439099
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=872, family=extra_trees
# CV AUC mean: 0.8617911467032451
# CV AUC std: 0.003542062850020433
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=873, family=extra_trees
# CV AUC mean: 0.8622752998024208
# CV AUC std: 0.003786255062213244
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=874, family=extra_trees
# CV AUC mean: 0.8506880485103169
# CV AUC std: 0.004114936178979719
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=875, family=extra_trees
# CV AUC mean: 0.8708213518362763
# CV AUC std: 0.0032870344927797175
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=876, family=extra_trees
# CV AUC mean: 0.8679126752338643
# CV AUC std: 0.003069236649898704
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=877, family=random_forest
# CV AUC mean: 0.8552863628618811
# CV AUC std: 0.004574459986022013
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=878, family=random_forest
# CV AUC mean: 0.8629362263932695
# CV AUC std: 0.003930124917502935
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=879, family=extra_trees
# CV AUC mean: 0.8586047448342928
# CV AUC std: 0.0030221927340301387
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=880, family=random_forest
# CV AUC mean: 0.8573905715532517
# CV AUC std: 0.004132300781037198
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=881, family=random_forest
# CV AUC mean: 0.8587087770882003
# CV AUC std: 0.004701382982421348
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=882, family=random_forest
# CV AUC mean: 0.8442513008153476
# CV AUC std: 0.004696443855069811
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=883, family=random_forest
# CV AUC mean: 0.8593551099361092
# CV AUC std: 0.0040294786966953
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=884, family=random_forest
# CV AUC mean: 0.8511179511963256
# CV AUC std: 0.0036333153769115365
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=885, family=random_forest
# CV AUC mean: 0.8486749341308402
# CV AUC std: 0.0036671639702413376
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=886, family=random_forest
# CV AUC mean: 0.8573228995871263
# CV AUC std: 0.004180838645441222
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=887, family=random_forest
# CV AUC mean: 0.8425829734559718
# CV AUC std: 0.005177339298167644
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=888, family=extra_trees
# CV AUC mean: 0.8614408092031101
# CV AUC std: 0.002775345310174737
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=889, family=extra_trees
# CV AUC mean: 0.8744887974258428
# CV AUC std: 0.0038001850465187296
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=890, family=extra_trees
# CV AUC mean: 0.8475217781967987
# CV AUC std: 0.003798344739691699
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=891, family=extra_trees
# CV AUC mean: 0.8660294273796714
# CV AUC std: 0.004424704425320447
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=892, family=extra_trees
# CV AUC mean: 0.868047003003977
# CV AUC std: 0.004630352869884483
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=893, family=extra_trees
# CV AUC mean: 0.8726143311120571
# CV AUC std: 0.0037224377533226867
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=894, family=random_forest
# CV AUC mean: 0.8425873109444781
# CV AUC std: 0.00423390847375142
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=895, family=extra_trees
# CV AUC mean: 0.8696504413696932
# CV AUC std: 0.003037523086031987
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=896, family=extra_trees
# CV AUC mean: 0.8621848492913315
# CV AUC std: 0.002771352803282552
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=897, family=extra_trees
# CV AUC mean: 0.8773057704186128
# CV AUC std: 0.0029979273791907067
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=898, family=random_forest
# CV AUC mean: 0.8624233721642856
# CV AUC std: 0.004117462741095662
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=899, family=random_forest
# CV AUC mean: 0.8432541961087903
# CV AUC std: 0.0033237660365186173
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=900, family=extra_trees
# CV AUC mean: 0.8577138963337274
# CV AUC std: 0.004046846308095765
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=901, family=extra_trees
# CV AUC mean: 0.8540570951284112
# CV AUC std: 0.004328092874765148
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=902, family=random_forest
# CV AUC mean: 0.847997959032034
# CV AUC std: 0.004841477514638472
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=903, family=random_forest
# CV AUC mean: 0.8463607265032034
# CV AUC std: 0.004814523135483557
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=904, family=extra_trees
# CV AUC mean: 0.8696498988789028
# CV AUC std: 0.0031387397396346966
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=905, family=random_forest
# CV AUC mean: 0.8437834445192642
# CV AUC std: 0.004241110650942705
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=906, family=random_forest
# CV AUC mean: 0.8439118317074218
# CV AUC std: 0.004333739093764999
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=907, family=extra_trees
# CV AUC mean: 0.862266035219926
# CV AUC std: 0.004010109009509419
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=908, family=extra_trees
# CV AUC mean: 0.8646579938423793
# CV AUC std: 0.004038357490366677
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=909, family=extra_trees
# CV AUC mean: 0.8674783422422871
# CV AUC std: 0.003540453125739166
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=910, family=random_forest
# CV AUC mean: 0.843121122943983
# CV AUC std: 0.004411658130235108
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=911, family=random_forest
# CV AUC mean: 0.8497166558461862
# CV AUC std: 0.004632496085751065
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=912, family=random_forest
# CV AUC mean: 0.8546444223869832
# CV AUC std: 0.0035383192454471767
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=913, family=random_forest
# CV AUC mean: 0.8468150014001198
# CV AUC std: 0.004548251525189266
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=914, family=extra_trees
# CV AUC mean: 0.8721336764763968
# CV AUC std: 0.004218238331607315
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=915, family=random_forest
# CV AUC mean: 0.8605408121570974
# CV AUC std: 0.003911317689564995
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=916, family=random_forest
# CV AUC mean: 0.847314632079323
# CV AUC std: 0.005284845209259359
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=917, family=extra_trees
# CV AUC mean: 0.870752749752328
# CV AUC std: 0.003392503441837274
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=918, family=random_forest
# CV AUC mean: 0.8518968892218373
# CV AUC std: 0.004360766258275925
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=919, family=extra_trees
# CV AUC mean: 0.8626114409866545
# CV AUC std: 0.004240573138088213
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=920, family=extra_trees
# CV AUC mean: 0.8772216490581991
# CV AUC std: 0.0032414181362025686
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=921, family=extra_trees
# CV AUC mean: 0.8364848431284149
# CV AUC std: 0.002962401282590292
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=922, family=extra_trees
# CV AUC mean: 0.8586782887757767
# CV AUC std: 0.003882812972948148
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=923, family=random_forest
# CV AUC mean: 0.8570067330327096
# CV AUC std: 0.00433481079450418
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=924, family=random_forest
# CV AUC mean: 0.8464901023815413
# CV AUC std: 0.004172749324206436
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=925, family=logistic_regression
# CV AUC mean: 0.8594921913562918
# CV AUC std: 0.0023796533165857526
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=926, family=logistic_regression
# CV AUC mean: 0.8594498299825968
# CV AUC std: 0.0023915905480219675
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=927, family=logistic_regression
# CV AUC mean: 0.835512970929044
# CV AUC std: 0.003539136213479284
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=928, family=logistic_regression
# CV AUC mean: 0.8594888534291858
# CV AUC std: 0.002379922776505379
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=929, family=logistic_regression
# CV AUC mean: 0.8591867757198507
# CV AUC std: 0.0024543474192039376
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=930, family=logistic_regression
# CV AUC mean: 0.8595048984186293
# CV AUC std: 0.002379606543629894
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=931, family=logistic_regression
# CV AUC mean: 0.8594921913562918
# CV AUC std: 0.0023796533165857526
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=932, family=logistic_regression
# CV AUC mean: 0.8594949647260138
# CV AUC std: 0.002375605916021606
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=933, family=logistic_regression
# CV AUC mean: 0.8594986101139638
# CV AUC std: 0.002376710573037045
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=934, family=logistic_regression
# CV AUC mean: 0.8594952717438705
# CV AUC std: 0.002375438590412822
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=935, family=logistic_regression
# CV AUC mean: 0.8594937282881185
# CV AUC std: 0.0023777490419772413
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=936, family=logistic_regression
# CV AUC mean: 0.8594949993020282
# CV AUC std: 0.0023755917003753235
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=937, family=logistic_regression
# CV AUC mean: 0.8595048984186293
# CV AUC std: 0.002379606543629894
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=938, family=logistic_regression
# CV AUC mean: 0.8594921913562918
# CV AUC std: 0.0023796533165857526
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=939, family=logistic_regression
# CV AUC mean: 0.8594952150429844
# CV AUC std: 0.0023754473626937836
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=940, family=logistic_regression
# CV AUC mean: 0.8594936826470704
# CV AUC std: 0.002377644436645547
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=941, family=logistic_regression
# CV AUC mean: 0.8355127026583642
# CV AUC std: 0.003539200003828974
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=942, family=logistic_regression
# CV AUC mean: 0.8355127317067514
# CV AUC std: 0.0035392400861856024
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=943, family=logistic_regression
# CV AUC mean: 0.835512735846436
# CV AUC std: 0.0035390444819641733
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=944, family=logistic_regression
# CV AUC mean: 0.8595474021559957
# CV AUC std: 0.002387632645300336
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=945, family=logistic_regression
# CV AUC mean: 0.8594937061592738
# CV AUC std: 0.0023777639219482926
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=946, family=logistic_regression
# CV AUC mean: 0.8565328520699916
# CV AUC std: 0.0027430023190037514
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=947, family=logistic_regression
# CV AUC mean: 0.859490747539936
# CV AUC std: 0.002379103567153404
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=948, family=logistic_regression
# CV AUC mean: 0.8594905483919462
# CV AUC std: 0.002379086676795305
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=949, family=logistic_regression
# CV AUC mean: 0.8594951500492825
# CV AUC std: 0.0023752900284974457
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=950, family=logistic_regression
# CV AUC mean: 0.859496050318859
# CV AUC std: 0.0023756240356231748
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=951, family=logistic_regression
# CV AUC mean: 0.8595232943628162
# CV AUC std: 0.0023841669283789276
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=952, family=logistic_regression
# CV AUC mean: 0.8594948305176324
# CV AUC std: 0.002376043977849411
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=953, family=logistic_regression
# CV AUC mean: 0.8355128340361556
# CV AUC std: 0.0035393323609606364
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=954, family=logistic_regression
# CV AUC mean: 0.8594951500492825
# CV AUC std: 0.0023752900284974457
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=955, family=logistic_regression
# CV AUC mean: 0.8594888810942146
# CV AUC std: 0.0023800519083551955
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=956, family=logistic_regression
# CV AUC mean: 0.8594954418434732
# CV AUC std: 0.0023754340857548234
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=957, family=logistic_regression
# CV AUC mean: 0.8591868019935752
# CV AUC std: 0.0024544457971413516
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=958, family=logistic_regression
# CV AUC mean: 0.8594951583405701
# CV AUC std: 0.0023753892605594094
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=959, family=logistic_regression
# CV AUC mean: 0.8594952800424929
# CV AUC std: 0.002375431335986676
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=960, family=logistic_regression
# CV AUC mean: 0.8594936577579266
# CV AUC std: 0.0023777352489285537
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=961, family=logistic_regression
# CV AUC mean: 0.8594904806345834
# CV AUC std: 0.0023791106873941857
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=962, family=logistic_regression
# CV AUC mean: 0.8565328078141358
# CV AUC std: 0.0027430257338075005
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=963, family=logistic_regression
# CV AUC mean: 0.8355127081820182
# CV AUC std: 0.0035392843132534962
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=964, family=logistic_regression
# CV AUC mean: 0.8594986101139638
# CV AUC std: 0.002376710573037045
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=965, family=logistic_regression
# CV AUC mean: 0.8565327815422448
# CV AUC std: 0.002742994135874739
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=966, family=logistic_regression
# CV AUC mean: 0.8565327884562863
# CV AUC std: 0.0027430053997808614
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=967, family=logistic_regression
# CV AUC mean: 0.8594905483919462
# CV AUC std: 0.002379086676795305
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=968, family=logistic_regression
# CV AUC mean: 0.8595048984186293
# CV AUC std: 0.002379606543629894
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=969, family=logistic_regression
# CV AUC mean: 0.8594951500492825
# CV AUC std: 0.0023752900284974457
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=970, family=logistic_regression
# CV AUC mean: 0.8595142327753766
# CV AUC std: 0.0023855238644300844
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=971, family=logistic_regression
# CV AUC mean: 0.8594911582879752
# CV AUC std: 0.0023793243833836217
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=972, family=logistic_regression
# CV AUC mean: 0.8591868047602922
# CV AUC std: 0.0024543490195820207
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=973, family=logistic_regression
# CV AUC mean: 0.8594949619519623
# CV AUC std: 0.0023755721192740033
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=974, family=logistic_regression
# CV AUC mean: 0.8594937545627598
# CV AUC std: 0.002377805807363556
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=975, family=logistic_regression
# CV AUC mean: 0.8565328686629579
# CV AUC std: 0.002742982631892105
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=976, family=logistic_regression
# CV AUC mean: 0.8594889142816754
# CV AUC std: 0.002380050288362013
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=977, family=logistic_regression
# CV AUC mean: 0.8594986101139638
# CV AUC std: 0.002376710573037045
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=978, family=logistic_regression
# CV AUC mean: 0.8594937213881352
# CV AUC std: 0.0023779120964992216
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=979, family=logistic_regression
# CV AUC mean: 0.8594921913562918
# CV AUC std: 0.0023796533165857526
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=980, family=logistic_regression
# CV AUC mean: 0.8594951500492825
# CV AUC std: 0.0023752900284974457
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=981, family=logistic_regression
# CV AUC mean: 0.8594948139286391
# CV AUC std: 0.002376092581034059
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=982, family=logistic_regression
# CV AUC mean: 0.8594937614768015
# CV AUC std: 0.0023777719960656582
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=983, family=logistic_regression
# CV AUC mean: 0.8594950324959066
# CV AUC std: 0.0023752046448602938
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=984, family=logistic_regression
# CV AUC mean: 0.8594952274922933
# CV AUC std: 0.0023754499927725577
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=985, family=logistic_regression
# CV AUC mean: 0.8594904806345834
# CV AUC std: 0.0023791106873941857
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=986, family=logistic_regression
# CV AUC mean: 0.8594888299249284
# CV AUC std: 0.002380019458962327
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=987, family=logistic_regression
# CV AUC mean: 0.8594951500492825
# CV AUC std: 0.0023752900284974457
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=988, family=logistic_regression
# CV AUC mean: 0.8565327995295716
# CV AUC std: 0.002743066654780406
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=989, family=logistic_regression
# CV AUC mean: 0.8594951887689541
# CV AUC std: 0.002375404270652212
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=990, family=logistic_regression
# CV AUC mean: 0.8594888271557668
# CV AUC std: 0.002380012821464408
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=991, family=logistic_regression
# CV AUC mean: 0.8591868241202809
# CV AUC std: 0.0024544246273996216
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=992, family=logistic_regression
# CV AUC mean: 0.8595048984186293
# CV AUC std: 0.002379606543629894
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=993, family=logistic_regression
# CV AUC mean: 0.859496050318859
# CV AUC std: 0.0023756240356231748
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=994, family=logistic_regression
# CV AUC mean: 0.8591867466763532
# CV AUC std: 0.0024544749619115755
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=995, family=logistic_regression
# CV AUC mean: 0.8594986101139638
# CV AUC std: 0.002376710573037045
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=996, family=logistic_regression
# CV AUC mean: 0.8594936785009681
# CV AUC std: 0.0023778009963004464
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=997, family=logistic_regression
# CV AUC mean: 0.8594953513461915
# CV AUC std: 0.0023805579846970892
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=998, family=logistic_regression
# CV AUC mean: 0.8594950864300761
# CV AUC std: 0.002375256549208218
# Saved progress to ../results/santander/santander_1000_model_results.csv
#
# Running model_id=999, family=logistic_regression
# CV AUC mean: 0.8594950131230823
# CV AUC std: 0.0023756354597333456
# Saved progress to ../results/santander/santander_1000_model_results.csv
# Batch complete.
# New results: 300

# %%
results_df = pd.read_csv(RESULTS_CSV)

print("Results shape:", results_df.shape)
display(results_df.tail())

print("\nModel family counts:")
display(results_df["model_family"].value_counts())

print("\nSubmission status:")
display(results_df["submitted_to_kaggle"].value_counts(dropna=False))
# Out:
# Results shape: (700, 22)
#     competition  model_id model_family    seed  \
# 695   santander       695      xgboost  432335
# 696   santander       696      xgboost  442149
# 697   santander       697      xgboost  749729
# 698   santander       698      xgboost  588268
# 699   santander       699      xgboost  816357
#
#                                            params_json  \
# 695  {"n_estimators": 1100, "learning_rate": 0.07, ...
# 696  {"n_estimators": 500, "learning_rate": 0.05, "...
# 697  {"n_estimators": 500, "learning_rate": 0.05, "...
# 698  {"n_estimators": 1100, "learning_rate": 0.01, ...
# 699  {"n_estimators": 500, "learning_rate": 0.05, "...
#
#                      started_at  cv_auc_mean  cv_auc_std  cv_auc_min  \
# 695  2026-05-10T19:16:24.593720     0.891114    0.002775    0.885904
# 696  2026-05-10T19:19:04.319066     0.874270    0.003531    0.867773
# 697  2026-05-10T19:20:06.819457     0.881168    0.003509    0.874561
# 698  2026-05-10T19:21:17.690857     0.877325    0.003338    0.870932
# 699  2026-05-10T19:24:59.498090     0.886200    0.002554    0.881266
#
#      cv_auc_max  ... kaggle_status  public_auc private_auc  runtime_seconds  \
# 695    0.893728  ...           NaN         NaN         NaN       159.706964
# 696    0.878091  ...           NaN         NaN         NaN        62.486246
# 697    0.884468  ...           NaN         NaN         NaN        70.856670
# 698    0.880513  ...           NaN         NaN         NaN       221.790746
# 699    0.888389  ...           NaN         NaN         NaN        95.570195
#
#      error                 finished_at  cv_private_gap abs_cv_private_gap  \
# 695    NaN  2026-05-10T19:19:04.300676             NaN                NaN
# 696    NaN  2026-05-10T19:20:06.805302             NaN                NaN
# 697    NaN  2026-05-10T19:21:17.676118             NaN                NaN
# 698    NaN  2026-05-10T19:24:59.481595             NaN                NaN
# 699    NaN  2026-05-10T19:26:35.068276             NaN                NaN
#
#      public_private_gap  abs_public_private_gap
# 695                 NaN                     NaN
# 696                 NaN                     NaN
# 697                 NaN                     NaN
# 698                 NaN                     NaN
# 699                 NaN                     NaN
#
# [5 rows x 22 columns]
# Model family counts:
# model_family
# lightgbm    350
# xgboost     350
# Name: count, dtype: int64
# Submission status:
# submitted_to_kaggle
# False    699
# True       1
# Name: count, dtype: int64

# %% [markdown]
# ## 11. Validation Reliability Metrics
#
# Once public and private leaderboard scores are available, calculate:
#
# - CV bias: `cv_auc_mean - private_auc`
# - Public leaderboard bias: `public_auc - private_auc`
# - Absolute CV-private gap
# - Absolute public-private gap
#
# These metrics are the empirical foundation for the Bayesian melding model.

# %%
results_df = pd.read_csv(RESULTS_CSV)

results_df["cv_private_gap"] = results_df["cv_auc_mean"] - results_df["private_auc"]
results_df["abs_cv_private_gap"] = results_df["cv_private_gap"].abs()

results_df["public_private_gap"] = results_df["public_auc"] - results_df["private_auc"]
results_df["abs_public_private_gap"] = results_df["public_private_gap"].abs()

results_df.to_csv(RESULTS_CSV, index=False)

scored_df = results_df.dropna(subset=["public_auc", "private_auc"]).copy()

print("Total results:", len(results_df))
print("Rows with Kaggle public/private scores:", len(scored_df))

display(scored_df.head())
# Out:
# Total results: 700
# Rows with Kaggle public/private scores: 1
#   competition  model_id model_family    seed  \
# 5   santander         5     lightgbm  759899
#
#                                          params_json  \
# 5  {"n_estimators": 300, "learning_rate": 0.02, "...
#
#                    started_at  cv_auc_mean  cv_auc_std  cv_auc_min  \
# 5  2026-05-09T21:44:22.964176     0.842029    0.003576     0.83614
#
#    cv_auc_max  ... kaggle_status  public_auc private_auc  runtime_seconds  \
# 5    0.846747  ...      COMPLETE     0.84053     0.83816        124.96117
#
#    error                 finished_at  cv_private_gap abs_cv_private_gap  \
# 5    NaN  2026-05-09T21:46:27.925343        0.003869           0.003869
#
#    public_private_gap  abs_public_private_gap
# 5             0.00237                 0.00237
#
# [1 rows x 22 columns]

# %%
if len(scored_df) > 0:
    summary_by_family = scored_df.groupby("model_family").agg(
        n_models=("model_id", "count"),
        mean_cv_auc=("cv_auc_mean", "mean"),
        mean_public_auc=("public_auc", "mean"),
        mean_private_auc=("private_auc", "mean"),
        mean_cv_private_gap=("cv_private_gap", "mean"),
        mean_abs_cv_private_gap=("abs_cv_private_gap", "mean"),
        mean_public_private_gap=("public_private_gap", "mean"),
        mean_abs_public_private_gap=("abs_public_private_gap", "mean"),
        mean_cv_std=("cv_auc_std", "mean")
    ).reset_index()

    display(summary_by_family)

    summary_path = RESULTS_DIR / "santander_summary_by_family.csv"
    summary_by_family.to_csv(summary_path, index=False)
    print("Saved:", summary_path)
else:
    print("No scored Kaggle submissions yet.")
# Out:
#   model_family  n_models  mean_cv_auc  mean_public_auc  mean_private_auc  \
# 0     lightgbm         1     0.842029          0.84053           0.83816
#
#    mean_cv_private_gap  mean_abs_cv_private_gap  mean_public_private_gap  \
# 0             0.003869                 0.003869                  0.00237
#
#    mean_abs_public_private_gap  mean_cv_std
# 0                      0.00237     0.003576
# Saved: ../results/santander/santander_summary_by_family.csv

# %%
if len(scored_df) >= 3:
    corr_cols = ["cv_auc_mean", "public_auc", "private_auc"]
    corr_matrix = scored_df[corr_cols].corr()

    print("Correlation matrix:")
    display(corr_matrix)

    corr_path = RESULTS_DIR / "santander_score_correlations.csv"
    corr_matrix.to_csv(corr_path)
    print("Saved:", corr_path)
else:
    print("Need at least 3 scored submissions for correlation analysis.")
# Out:
# Need at least 3 scored submissions for correlation analysis.

# %%
if len(scored_df) > 0:
    plt.figure(figsize=(8, 6))
    plt.scatter(scored_df["cv_auc_mean"], scored_df["private_auc"])
    plt.xlabel("5-Fold CV AUC")
    plt.ylabel("Private Leaderboard AUC")
    plt.title("Santander: CV AUC vs Private Leaderboard AUC")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.scatter(scored_df["public_auc"], scored_df["private_auc"])
    plt.xlabel("Public Leaderboard AUC")
    plt.ylabel("Private Leaderboard AUC")
    plt.title("Santander: Public vs Private Leaderboard AUC")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.hist(scored_df["cv_private_gap"], bins=20)
    plt.xlabel("CV AUC - Private AUC")
    plt.ylabel("Count")
    plt.title("Santander: CV Bias Distribution")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("No scored rows available for plotting.")

# %%
results_df = pd.read_csv(RESULTS_CSV)

bayesian_cols = [
    "competition",
    "model_id",
    "model_family",
    "seed",
    "params_json",
    "cv_auc_mean",
    "cv_auc_std",
    "cv_auc_min",
    "cv_auc_max",
    "public_auc",
    "private_auc",
    "cv_private_gap",
    "abs_cv_private_gap",
    "public_private_gap",
    "abs_public_private_gap",
    "runtime_seconds"
]

available_cols = [c for c in bayesian_cols if c in results_df.columns]

bayesian_df = results_df[available_cols].copy()

bayesian_output_path = RESULTS_DIR / "santander_bayesian_melding_input.csv"
bayesian_df.to_csv(bayesian_output_path, index=False)

print("Saved Bayesian melding input dataset to:")
print(bayesian_output_path)

display(bayesian_df.head())
# Out:
# Saved Bayesian melding input dataset to:
# ../results/santander/santander_bayesian_melding_input.csv
#   competition  model_id model_family    seed  \
# 0   santander         0     lightgbm   89251
# 1   santander         1     lightgbm  526479
# 2   santander         2     lightgbm  500352
# 3   santander         3     lightgbm  450460
# 4   santander         4     lightgbm  165229
#
#                                          params_json  cv_auc_mean  cv_auc_std  \
# 0  {"n_estimators": 900, "learning_rate": 0.05, "...     0.889728    0.002818
# 1  {"n_estimators": 1100, "learning_rate": 0.05, ...     0.889192    0.001899
# 2  {"n_estimators": 500, "learning_rate": 0.01, "...     0.850518    0.003843
# 3  {"n_estimators": 500, "learning_rate": 0.01, "...     0.855446    0.003695
# 4  {"n_estimators": 900, "learning_rate": 0.05, "...     0.892348    0.002643
#
#    cv_auc_min  cv_auc_max  public_auc  private_auc  cv_private_gap  \
# 0    0.884272    0.891965         NaN          NaN             NaN
# 1    0.885516    0.890977         NaN          NaN             NaN
# 2    0.843968    0.855834         NaN          NaN             NaN
# 3    0.848831    0.860221         NaN          NaN             NaN
# 4    0.887471    0.895040         NaN          NaN             NaN
#
#    abs_cv_private_gap  public_private_gap  abs_public_private_gap  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#    runtime_seconds
# 0        95.393856
# 1       119.814146
# 2        87.007270
# 3       111.966728
# 4       172.636391

# %%
results_df = pd.read_csv(RESULTS_CSV)

print("Shape:", results_df.shape)

display(results_df["model_family"].value_counts())

summary = results_df.groupby("model_family").agg(
    n_models=("model_id", "count"),
    mean_cv=("cv_auc_mean", "mean"),
    std_cv=("cv_auc_mean", "std"),
    min_cv=("cv_auc_mean", "min"),
    max_cv=("cv_auc_mean", "max"),
    mean_fold_std=("cv_auc_std", "mean"),
    mean_runtime=("runtime_seconds", "mean")
).reset_index()

display(summary.sort_values("mean_cv", ascending=False))

display(
    results_df.sort_values("cv_auc_mean", ascending=False)
    [["model_id", "model_family", "cv_auc_mean", "cv_auc_std", "runtime_seconds"]]
    .head(20)
)
# Out:
# Shape: (700, 22)
# model_family
# lightgbm    350
# xgboost     350
# Name: count, dtype: int64
#   model_family  n_models   mean_cv    std_cv    min_cv    max_cv  \
# 1      xgboost       350  0.872785  0.018876  0.786212  0.894661
# 0     lightgbm       350  0.872761  0.020897  0.785353  0.894082
#
#    mean_fold_std  mean_runtime
# 1       0.003331    117.768667
# 0       0.003300    101.078241
#      model_id model_family  cv_auc_mean  cv_auc_std  runtime_seconds
# 472       472      xgboost     0.894661    0.002756       135.468755
# 462       462      xgboost     0.894470    0.002423       125.415334
# 294       294     lightgbm     0.894082    0.003190       122.331770
# 169       169     lightgbm     0.893957    0.002295       133.588933
# 479       479      xgboost     0.893952    0.002559       149.416798
# 84         84     lightgbm     0.893764    0.002688        88.280971
# 371       371      xgboost     0.893757    0.002653       144.169865
# 81         81     lightgbm     0.893692    0.002318       107.758518
# 19         19     lightgbm     0.893636    0.002746       103.919501
# 412       412      xgboost     0.893617    0.002449       143.185722
# 253       253     lightgbm     0.893606    0.002088       112.011130
# 67         67     lightgbm     0.893405    0.002755       105.877071
# 72         72     lightgbm     0.893369    0.002836        92.340557
# 21         21     lightgbm     0.893359    0.002779        91.469780
# 60         60     lightgbm     0.893342    0.002627       100.321867
# 96         96     lightgbm     0.893187    0.002382        76.086684
# 571       571      xgboost     0.893166    0.002735       206.805060
# 333       333     lightgbm     0.893124    0.002899       313.877513
# 532       532      xgboost     0.893111    0.002688       151.077654
# 280       280     lightgbm     0.893042    0.002325        78.380360

# %% [markdown]
# ## 12. Representative Leaderboard Subset Selection
#
# This section selects a representative subset of 100 Santander models for leaderboard evaluation.
#
# The subset is selected across model families and cross-validation performance ranges rather than taking only the best-performing models. This reduces cherry-picking risk and supports fairer validation reliability analysis.
#
# Random Forest and ExtraTrees are grouped into a combined `bagging_trees` category for subset allocation.

# %%
results_df = pd.read_csv(RESULTS_CSV)

# Keep only rows with generated submission files.
available_df = results_df[
    results_df["submission_path"].notna()
].copy()

# Treat Random Forest and ExtraTrees as one combined bagging family.
available_df["submission_family"] = available_df["model_family"].replace({
    "random_forest": "bagging_trees",
    "extra_trees": "bagging_trees"
})

family_quota = {
    "lightgbm": 25,
    "xgboost": 25,
    "catboost": 20,
    "bagging_trees": 15,
    "logistic_regression": 15
}

def select_top_middle_bottom(group_df, n_select):
    group_df = group_df.sort_values("cv_auc_mean").copy()

    n_bottom = n_select // 3
    n_top = n_select // 3
    n_middle = n_select - n_bottom - n_top

    bottom = group_df.head(n_bottom)
    top = group_df.tail(n_top)

    median_cv = group_df["cv_auc_mean"].median()
    middle = (
        group_df
        .assign(distance_to_median=(group_df["cv_auc_mean"] - median_cv).abs())
        .sort_values("distance_to_median")
        .head(n_middle)
    )

    selected = pd.concat([top, middle, bottom], ignore_index=True)
    selected = selected.drop_duplicates(subset=["model_id"])

    return selected

selected_parts = []

for family, quota in family_quota.items():
    family_df = available_df[available_df["submission_family"] == family].copy()

    selected_family = select_top_middle_bottom(
        group_df=family_df,
        n_select=quota
    )

    selected_parts.append(selected_family)

manual_submission_plan = (
    pd.concat(selected_parts, ignore_index=True)
    .drop_duplicates(subset=["model_id"])
    .sort_values(["submission_family", "cv_auc_mean"], ascending=[True, False])
)

manual_submission_plan_path = RESULTS_DIR / "manual_submission_plan_100.csv"
manual_submission_plan.to_csv(manual_submission_plan_path, index=False)

print("Manual submission plan size:", len(manual_submission_plan))
print("Saved to:", manual_submission_plan_path)

display(
    manual_submission_plan[
        [
            "model_id",
            "model_family",
            "submission_family",
            "cv_auc_mean",
            "cv_auc_std",
            "submission_path"
        ]
    ]
)
# Out:
# Manual submission plan size: 100
# Saved to: ../results/santander/manual_submission_plan_100.csv
#     model_id model_family submission_family  cv_auc_mean  cv_auc_std  \
# 74       897  extra_trees     bagging_trees     0.877306    0.002998
# 73       920  extra_trees     bagging_trees     0.877222    0.003241
# 72       889  extra_trees     bagging_trees     0.874489    0.003800
# 71       893  extra_trees     bagging_trees     0.872614    0.003722
# 70       914  extra_trees     bagging_trees     0.872134    0.004218
# ..       ...          ...               ...          ...         ...
# 46       630      xgboost           xgboost     0.813279    0.004251
# 45       631      xgboost           xgboost     0.812329    0.004034
# 44       385      xgboost           xgboost     0.805393    0.004878
# 43       576      xgboost           xgboost     0.790928    0.005571
# 42       484      xgboost           xgboost     0.786212    0.005682
#
#                                       submission_path
# 74  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 73  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 72  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 71  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 70  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# ..                                                ...
# 46  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 45  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 44  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 43  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
# 42  /Users/kunalgurung/Desktop/UTS SEM4/36126/proj...
#
# [100 rows x 6 columns]

# %% [markdown]
# ## 13. Manual Leaderboard Score Integration
#
# This section records the manually verified Kaggle public and private leaderboard scores for the selected Santander representative models.
#
# Leaderboard scores were collected manually because large-scale automated submission and score retrieval was limited by Kaggle submission-rate constraints.
#
# The manually verified scores are saved as `santander_leaderboard_scores.csv`.

# %%
# MANUAL SANTANDER LEADERBOARD SCORES
leaderboard_records = [
    # model_id, public_auc, private_auc
    [10, 0.88063, 0.87641],
    [19, 0.89457, 0.89159],
    [52, 0.78596, 0.78164],
    [67, 0.89304, 0.89027],
    [72, 0.89470, 0.89052],
    [75, 0.81146, 0.80607],
    [81, 0.89509, 0.89165],
    [84, 0.89444, 0.89133],
    [86, 0.88044, 0.87764],
    [117, 0.87972, 0.87655],
    [143, 0.78526, 0.78079],
    [145, 0.80686, 0.80215],
    [154, 0.80995, 0.80521],
    [168, 0.78516, 0.78157],
    [169, 0.89549, 0.89218],
    [184, 0.88151, 0.87819],
    [190, 0.88002, 0.87708],
    [222, 0.80967, 0.80400],
    [240, 0.88056, 0.87698],
    [244, 0.80728, 0.80226],
    [253, 0.89443, 0.89139],
    [274, 0.87930, 0.87647],
    [294, 0.89452, 0.89197],
    [327, 0.88035, 0.87648],
    [339, 0.87949, 0.87703],
    [371, 0.89479, 0.89164],
    [385, 0.80290, 0.79875],
    [387, 0.87961, 0.87643],
    [412, 0.89388, 0.89262],
    [441, 0.87853, 0.87504],
    [442, 0.89357, 0.89090],
    [445, 0.87865, 0.87489],
    [455, 0.81539, 0.81233],
    [459, 0.81938, 0.81532],
    [462, 0.89455, 0.89210],
    [472, 0.89414, 0.89182],
    [479, 0.89545, 0.89206],
    [484, 0.78554, 0.78129],
    [505, 0.87872, 0.87581],
    [532, 0.89324, 0.88967],
    [563, 0.87810, 0.87465],
    [571, 0.89328, 0.89010],
    [576, 0.78954, 0.78533],
    [585, 0.87828, 0.87430],
    [618, 0.87878, 0.87497],
    [619, 0.81918, 0.81472],
    [630, 0.81194, 0.80697],
    [631, 0.81167, 0.80724],
    [676, 0.87862, 0.87642],
    [681, 0.87794, 0.87413],
    [704, 0.89369, 0.89115],
    [707, 0.87194, 0.86984],
    [709, 0.81027, 0.80724],
    [724, 0.89444, 0.89141],
    [725, 0.86932, 0.86703],
    [751, 0.81426, 0.81085],
    [755, 0.87112, 0.86838],
    [761, 0.89516, 0.89267],
    [762, 0.89398, 0.89237],
    [764, 0.89401, 0.89191],
    [767, 0.86864, 0.86606],
    [769, 0.89418, 0.89150],
    [783, 0.80744, 0.80351],
    [785, 0.81799, 0.81422],
    [819, 0.87109, 0.86856],
    [822, 0.79548, 0.79184],
    [825, 0.87187, 0.86960],
    [827, 0.86845, 0.86580],
    [833, 0.87176, 0.86944],
    [841, 0.81599, 0.81226],
    [862, 0.83842, 0.83584],
    [864, 0.84184, 0.83639],
    [866, 0.85735, 0.85446],
    [868, 0.85447, 0.85206],
    [880, 0.85826, 0.85503],
    [886, 0.85720, 0.85444],
    [887, 0.84407, 0.83921],
    [889, 0.87385, 0.87221],
    [893, 0.87305, 0.87045],
    [894, 0.84299, 0.83937],
    [897, 0.87624, 0.87653],
    [900, 0.85901, 0.85604],
    [914, 0.87229, 0.86799],
    [920, 0.87754, 0.87564],
    [921, 0.83416, 0.83414],
    [930, 0.86096, 0.86066],
    [935, 0.86094, 0.86064],
    [937, 0.86096, 0.86066],
    [940, 0.86094, 0.86064],
    [941, 0.84430, 0.84406],
    [942, 0.84430, 0.84406],
    [943, 0.84430, 0.84406],
    [944, 0.86101, 0.86068],
    [945, 0.86094, 0.86064],
    [951, 0.86098, 0.86067],
    [953, 0.84430, 0.84406],
    [963, 0.84430, 0.84406],
    [970, 0.86097, 0.86066],
    [974, 0.86094, 0.86064],
    [978, 0.86094, 0.86064],
]

leaderboard_df = pd.DataFrame(
    leaderboard_records,
    columns=["model_id", "public_auc", "private_auc"]
)

leaderboard_df = (
    leaderboard_df
    .drop_duplicates(subset=["model_id"], keep="first")
    .sort_values("model_id")
    .reset_index(drop=True)
)

leaderboard_path = RESULTS_DIR / "santander_leaderboard_scores.csv"

leaderboard_df.to_csv(leaderboard_path, index=False)

print("Santander leaderboard rows:", len(leaderboard_df))
print("Saved leaderboard scores to:", leaderboard_path)

display(leaderboard_df.head())
display(leaderboard_df.tail())
# Out:
# Santander leaderboard rows: 100
# Saved leaderboard scores to: ../results/santander/santander_leaderboard_scores.csv
#    model_id  public_auc  private_auc
# 0        10     0.88063      0.87641
# 1        19     0.89457      0.89159
# 2        52     0.78596      0.78164
# 3        67     0.89304      0.89027
# 4        72     0.89470      0.89052
#     model_id  public_auc  private_auc
# 95       953     0.84430      0.84406
# 96       963     0.84430      0.84406
# 97       970     0.86097      0.86066
# 98       974     0.86094      0.86064
# 99       978     0.86094      0.86064

# %% [markdown]
# ## 14. Final Santander Research Dataset Construction
#
# This section merges the full cross-validation results with the manually verified leaderboard scores.
#
# It then computes the final validation reliability metrics:
#
# - `cv_private_gap`
# - `abs_cv_private_gap`
# - `public_private_gap`
# - `abs_public_private_gap`
#
# The output is saved as `santander_final_research_dataset.csv`.

# %%
# LOAD FULL CV RESULTS
results_df = pd.read_csv(RESULTS_CSV)

# REMOVE OLD/INCOMPLETE LEADERBOARD SCORE COLUMNS BEFORE MERGE
old_score_cols = [
    "public_auc",
    "private_auc",
    "cv_private_gap",
    "abs_cv_private_gap",
    "public_private_gap",
    "abs_public_private_gap"
]

results_df = results_df.drop(
    columns=[c for c in old_score_cols if c in results_df.columns],
    errors="ignore"
)

# MERGE CV RESULTS WITH CLEAN MANUAL LEADERBOARD SCORES
final_df = results_df.merge(
    leaderboard_df,
    on="model_id",
    how="inner"
)

# CREATE VALIDATION RELIABILITY METRICS
final_df["cv_private_gap"] = final_df["cv_auc_mean"] - final_df["private_auc"]
final_df["abs_cv_private_gap"] = final_df["cv_private_gap"].abs()

final_df["public_private_gap"] = final_df["public_auc"] - final_df["private_auc"]
final_df["abs_public_private_gap"] = final_df["public_private_gap"].abs()

final_df["competition"] = "santander"

# SAVE FINAL DATASET
final_dataset_path = RESULTS_DIR / "santander_final_research_dataset.csv"

final_df.to_csv(
    final_dataset_path,
    index=False
)

print("Final Santander research dataset rows:", len(final_df))
print("Saved final dataset to:", final_dataset_path)

display(
    final_df[
        [
            "competition",
            "model_id",
            "model_family",
            "cv_auc_mean",
            "cv_auc_std",
            "public_auc",
            "private_auc",
            "cv_private_gap",
            "public_private_gap"
        ]
    ].head()
)

display(
    final_df[
        [
            "competition",
            "model_id",
            "model_family",
            "cv_auc_mean",
            "cv_auc_std",
            "public_auc",
            "private_auc",
            "cv_private_gap",
            "public_private_gap"
        ]
    ].tail()
)
# Out:
# Final Santander research dataset rows: 100
# Saved final dataset to: ../results/santander/santander_final_research_dataset.csv
#   competition  model_id model_family  cv_auc_mean  cv_auc_std  public_auc  \
# 0   santander        10     lightgbm     0.880513    0.003094     0.88063
# 1   santander        19     lightgbm     0.893636    0.002746     0.89457
# 2   santander        52     lightgbm     0.785353    0.005842     0.78596
# 3   santander        67     lightgbm     0.893405    0.002755     0.89304
# 4   santander        72     lightgbm     0.893369    0.002836     0.89470
#
#    private_auc  cv_private_gap  public_private_gap
# 0      0.87641        0.004103             0.00422
# 1      0.89159        0.002046             0.00298
# 2      0.78164        0.003713             0.00432
# 3      0.89027        0.003135             0.00277
# 4      0.89052        0.002849             0.00418
#    competition  model_id         model_family  cv_auc_mean  cv_auc_std  \
# 95   santander       953  logistic_regression     0.835513    0.003539
# 96   santander       963  logistic_regression     0.835513    0.003539
# 97   santander       970  logistic_regression     0.859514    0.002386
# 98   santander       974  logistic_regression     0.859494    0.002378
# 99   santander       978  logistic_regression     0.859494    0.002378
#
#     public_auc  private_auc  cv_private_gap  public_private_gap
# 95     0.84430      0.84406       -0.008547             0.00024
# 96     0.84430      0.84406       -0.008547             0.00024
# 97     0.86097      0.86066       -0.001146             0.00031
# 98     0.86094      0.86064       -0.001146             0.00030
# 99     0.86094      0.86064       -0.001146             0.00030

# %% [markdown]
# ## 15. Final Dataset Validation Checks
#
# This section checks the final Santander research dataset for row counts, missing leaderboard scores, model-family coverage, and consistency between the representative submission plan and manually recorded leaderboard scores.

# %%
print("Rows:", len(final_df))
print("Unique model IDs:", final_df["model_id"].nunique())
print("Missing public scores:", final_df["public_auc"].isna().sum())
print("Missing private scores:", final_df["private_auc"].isna().sum())

display(final_df["model_family"].value_counts())
# Out:
# Rows: 100
# Unique model IDs: 100
# Missing public scores: 0
# Missing private scores: 0
# model_family
# lightgbm               25
# xgboost                25
# catboost               20
# logistic_regression    15
# extra_trees             9
# random_forest           6
# Name: count, dtype: int64

# %%
manual_plan_df = pd.read_csv(RESULTS_DIR / "manual_submission_plan_100.csv")

planned_ids = set(manual_plan_df["model_id"].astype(int))
leaderboard_ids = set(leaderboard_df["model_id"].astype(int))

missing_ids = sorted(planned_ids - leaderboard_ids)
extra_ids = sorted(leaderboard_ids - planned_ids)

print("Planned representative models:", len(planned_ids))
print("Leaderboard unique models:", len(leaderboard_ids))
print("Missing from leaderboard:", missing_ids)
print("Extra not in plan:", extra_ids)
# Out:
# Planned representative models: 100
# Leaderboard unique models: 100
# Missing from leaderboard: []
# Extra not in plan: []

# %% [markdown]
# ## Summary
#
# This notebook produces the Santander component of the final research dataset.
#
# The final Santander dataset contains cross-validation scores, manually verified public/private leaderboard scores, validation gap metrics, model family labels, and model configuration metadata.
#
# This output is later combined with the Porto and Homesite experiment outputs in:
#
# `04_final_analysis_bayesian_melding.ipynb`
